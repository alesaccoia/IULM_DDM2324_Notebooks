# %% [markdown]
# <a href="https://colab.research.google.com/github/alesaccoia/IULM_DDM2324_Notebooks/blob/main/31_NLP_su_Huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduzione a Huggingface

# %%
# !pip install huggingface

# %% [markdown]
# ## Importazione delle Librerie

# %%
from transformers import pipeline
import pandas as pd

# %% [markdown]
# ## Classificazione del testo
#
# La pipeline "text-classification" di default opera una sentiment analysis, con due classi: POSITIVE e NEGATIVE, ritornando la classe con probabilitá più elevata.
#
# Di default viene utilizzato il modello [distilbert-base-uncased-finetuned-sst-2-english](https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english), che é un fine tuning di BERT([Distilbert](https://huggingface.co/distilbert-base-uncased))

# %%
classifier = pipeline("text-classification")
outputs = classifier("This product is awful!")
pd.DataFrame(outputs)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
#       label     score
# 0  NEGATIVE  0.999804

# %% [markdown]
# Proviamo la pipeline in italiano:

# %%
outputs = classifier("Il prodotto funziona bene")
pd.DataFrame(outputs)
# Out:
#       label    score
# 0  POSITIVE  0.56688

# %% [markdown]
# ### Test con un modello multilingue
#
# Il modello [lxyuan/distilbert-base-multilingual-cased-sentiments-student](https://huggingface.co/lxyuan/distilbert-base-multilingual-cased-sentiments-student) ha avuto un training multilingua

# %%
classifier = pipeline("text-classification", model="lxyuan/distilbert-base-multilingual-cased-sentiments-student")

# %%
outputs = classifier("Il prodotto funziona bene")
pd.DataFrame(outputs)
# Out:
#       label     score
# 0  positive  0.883351

# %%
outputs = classifier("Sono veramente soddisfatto")
pd.DataFrame(outputs)
# Out:
#       label     score
# 0  negative  0.800071

# %% [markdown]
# # Zero-shot classification
#
# Si veda, per maggiori dettagli: [https://huggingface.co/tasks/zero-shot-classification](https://huggingface.co/tasks/zero-shot-classification)

# %%
from transformers import pipeline

# Inizializzare una pipeline per la classificazione del testo con un modello pre-addestrato di BERT
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# Esempi di descrizioni di prodotti
descrizioni_prodotti = [
    "Questo smartphone di ultima generazione offre una fotocamera ad alta risoluzione e un display OLED da 6.5 pollici.",
    "Scopri i sapori della cucina italiana con questo assortimento di pasta artigianale.",
    "Romantico romanzo ambientato nella Francia del XVIII secolo, ricco di avventura e passione.",
    "Potente laptop con processore i7, 16GB di RAM e scheda grafica dedicata, perfetto per il gaming e l'editing video."
]

# Categorie predefinite per la classificazione
categorie = ["Elettronica", "Cibo", "Libri", "Informatica"]

# Classificazione delle descrizioni
for descrizione in descrizioni_prodotti:
    risultati = classifier(descrizione, categorie)
    print(f"Descrizione: '{descrizione}'")
    print(f"Categoria predetta: {risultati['labels'][0]}")
    print("------")
# Out:
# Descrizione: 'Questo smartphone di ultima generazione offre una fotocamera ad alta risoluzione e un display OLED da 6.5 pollici.'
# Categoria predetta: Libri
# ------
# Descrizione: 'Scopri i sapori della cucina italiana con questo assortimento di pasta artigianale.'
# Categoria predetta: Cibo
# ------
# Descrizione: 'Romantico romanzo ambientato nella Francia del XVIII secolo, ricco di avventura e passione.'
# Categoria predetta: Libri
# ------
# Descrizione: 'Potente laptop con processore i7, 16GB di RAM e scheda grafica dedicata, perfetto per il gaming e l'editing video.'
# Categoria predetta: Elettronica
# ------
